# %%
name=input("Enter Name")
age=int(input("enter age:"))
dept=input("enter deparment:")
salary=float(input("enter salary:"))
print("\n_-----ID CARD-----")
print("Name:",name)
print("Department:",dept)
print("salary:",salary)
# Out:
# Enter Namevishalini
# enter age:18
# enter deparment:b.sc computer science
# enter salary:120000
#
# _-----ID CARD-----
# Name: vishalini
# Department: b.sc computer science
# salary: 120000.0

# %%
name=input("Enter Name")

# %%
total=0
for i in range(1,6):
    price=float(input(f"enter price of item{i}:"))
    total+=price
print("Total Bill =",total)
# Out:
# enter price of item1:80
# enter price of item2:60
# enter price of item3:70
# enter price of item4:50
# enter price of item5:90
# Total Bill = 350.0

# %%
total=0
for i in range(1,6):
    mark=float(input(f"enter mark{i}:"))
    total+=mark
percentage=total/5
print("percentage=",percentage,"%")
# Out:
# enter mark1:80
# enter mark2:70
# enter mark3:90
# enter mark4:65
# enter mark5:80
# percentage= 77.0 %

# %%
choice=int(input("1.celsius to fahrenheit\n2.fahremheit to celsius\nenter choice:"))
if choice==1:
   c=float(input("enter celsius:"))
   f=(c*9/5)+32
   print("fahrenheit=",f)
else:
  f=float(input("enter fahrenheit:"))
  c=(f-32)*5/9
  print("celsius=",c)
# Out:
# 1.celsius to fahrenheit
# 2.fahremheit to celsius
# enter choice:55
# enter fahrenheit:32
# celsius= 0.0

# %%
amount=float(input("enter recharge amount:"))
gst=float(input("enter gst %:"))
final=amount+(amount*gst/100)
print("final amount=",final)
# Out:
# enter recharge amount:350
# enter gst %:10
# final amount= 385.0

# %%
balance=float(input("enter balance:"))
withdraw=float(input("enter withdrawl amount:"))
if withdraw<=balance:
  print("withdrawl successful")
else:
  print("insufficient balance")
# Out:
# enter balance:1000
# enter withdrawl amount:500
# withdrawl successful

# %%
age=int(input("enter age:"))
if age>=18:
  print("eligible to vote")
else:
  print("not eligible")
# Out:
# enter age:19
# eligible to vote
